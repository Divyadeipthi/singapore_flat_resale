# %% [markdown]
# <a href="https://colab.research.google.com/github/Divyadeipthi/singapore_flat_resale/blob/main/falt_resale.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df1=pd.read_csv("/content/ResaleFlatPricesBasedonApprovalDate19901999.csv")
df1
# Out:
#           month        town  flat_type block       street_name storey_range  \
# 0       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4       1990-01  ANG MO KIO     3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
# ...         ...         ...        ...   ...               ...          ...
# 287191  1999-12      YISHUN  EXECUTIVE   611      YISHUN ST 61     10 TO 12
# 287192  1999-12      YISHUN  EXECUTIVE   324       YISHUN CTRL     01 TO 03
# 287193  1999-12      YISHUN  EXECUTIVE   392      YISHUN AVE 6     07 TO 09
# 287194  1999-12      YISHUN  EXECUTIVE   356    YISHUN RING RD     04 TO 06
# 287195  1999-12      YISHUN  EXECUTIVE   358    YISHUN RING RD     01 TO 03
#
# ...

# %%
df2=pd.read_csv("/content/ResaleFlatPricesBasedonRegistrationDateFromJan2015toDec2016.csv")
df2
# Out:
#          month        town         flat_type block        street_name  \
# 0      2015-01  ANG MO KIO            3 ROOM   174   ANG MO KIO AVE 4
# 1      2015-01  ANG MO KIO            3 ROOM   541  ANG MO KIO AVE 10
# 2      2015-01  ANG MO KIO            3 ROOM   163   ANG MO KIO AVE 4
# 3      2015-01  ANG MO KIO            3 ROOM   446  ANG MO KIO AVE 10
# 4      2015-01  ANG MO KIO            3 ROOM   557  ANG MO KIO AVE 10
# ...        ...         ...               ...   ...                ...
# 37148  2016-12      YISHUN            5 ROOM   297       YISHUN ST 20
# 37149  2016-12      YISHUN            5 ROOM   838       YISHUN ST 81
# 37150  2016-12      YISHUN         EXECUTIVE   664       YISHUN AVE 4
# 37151  2016-12      YISHUN         EXECUTIVE   325        YISHUN CTRL
# 37152  2016-12      YISHUN  MULTI-GENERATION   666       YISHUN AVE 4
#
#       storey_range  floor_area_sqm        flat_model  lease_commence_date  \
# ...

# %%
df3=pd.read_csv("/content/ResaleFlatPricesBasedonRegistrationDateFromMar2012toDec2014.csv")
df3
# Out:
#          month        town  flat_type block        street_name storey_range  \
# 0      2012-03  ANG MO KIO     2 ROOM   172   ANG MO KIO AVE 4     06 TO 10
# 1      2012-03  ANG MO KIO     2 ROOM   510   ANG MO KIO AVE 8     01 TO 05
# 2      2012-03  ANG MO KIO     3 ROOM   610   ANG MO KIO AVE 4     06 TO 10
# 3      2012-03  ANG MO KIO     3 ROOM   474  ANG MO KIO AVE 10     01 TO 05
# 4      2012-03  ANG MO KIO     3 ROOM   604   ANG MO KIO AVE 5     06 TO 10
# ...        ...         ...        ...   ...                ...          ...
# 52198  2014-12      YISHUN     5 ROOM   816       YISHUN ST 81     10 TO 12
# 52199  2014-12      YISHUN  EXECUTIVE   325        YISHUN CTRL     10 TO 12
# 52200  2014-12      YISHUN  EXECUTIVE   618     YISHUN RING RD     07 TO 09
# 52201  2014-12      YISHUN  EXECUTIVE   277       YISHUN ST 22     07 TO 09
# 52202  2014-12      YISHUN  EXECUTIVE   277       YISHUN ST 22     04 TO 06
#
# ...

# %%
df4=pd.read_csv("/content/ResaleflatpricesbasedonregistrationdatefromJan2017onwards.csv")
df4
# Out:
#           month        town  flat_type block        street_name storey_range  \
# 0       2017-01  ANG MO KIO     2 ROOM   406  ANG MO KIO AVE 10     10 TO 12
# 1       2017-01  ANG MO KIO     3 ROOM   108   ANG MO KIO AVE 4     01 TO 03
# 2       2017-01  ANG MO KIO     3 ROOM   602   ANG MO KIO AVE 5     01 TO 03
# 3       2017-01  ANG MO KIO     3 ROOM   465  ANG MO KIO AVE 10     04 TO 06
# 4       2017-01  ANG MO KIO     3 ROOM   601   ANG MO KIO AVE 5     01 TO 03
# ...         ...         ...        ...   ...                ...          ...
# 171323  2024-01      YISHUN  EXECUTIVE   325        YISHUN CTRL     04 TO 06
# 171324  2024-01      YISHUN  EXECUTIVE   356     YISHUN RING RD     04 TO 06
# 171325  2024-01      YISHUN  EXECUTIVE   360     YISHUN RING RD     04 TO 06
# 171326  2024-01      YISHUN  EXECUTIVE   387     YISHUN RING RD     10 TO 12
# 171327  2024-01      YISHUN  EXECUTIVE   606       YISHUN ST 61     04 TO 06
#
# ...

# %%
df5=pd.read_csv("/content/ResaleFlatPricesBasedonApprovalDate2000Feb2012.csv")
df5
# Out:
#           month        town  flat_type block       street_name storey_range  \
# 0       2000-01  ANG MO KIO     3 ROOM   170  ANG MO KIO AVE 4     07 TO 09
# 1       2000-01  ANG MO KIO     3 ROOM   174  ANG MO KIO AVE 4     04 TO 06
# 2       2000-01  ANG MO KIO     3 ROOM   216  ANG MO KIO AVE 1     07 TO 09
# 3       2000-01  ANG MO KIO     3 ROOM   215  ANG MO KIO AVE 1     07 TO 09
# 4       2000-01  ANG MO KIO     3 ROOM   218  ANG MO KIO AVE 1     07 TO 09
# ...         ...         ...        ...   ...               ...          ...
# 369646  2012-02      YISHUN     5 ROOM   212      YISHUN ST 21     10 TO 12
# 369647  2012-02      YISHUN     5 ROOM   758      YISHUN ST 72     01 TO 03
# 369648  2012-02      YISHUN     5 ROOM   873      YISHUN ST 81     01 TO 03
# 369649  2012-02      YISHUN  EXECUTIVE   664      YISHUN AVE 4     07 TO 09
# 369650  2012-02      YISHUN  EXECUTIVE   293      YISHUN ST 22     04 TO 06
#
# ...

# %%
data=pd.concat([df1,df2,df3,df4,df5],ignore_index=True)
data
# Out:
#           month        town  flat_type block       street_name storey_range  \
# 0       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4       1990-01  ANG MO KIO     3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
# ...         ...         ...        ...   ...               ...          ...
# 917526  2012-02      YISHUN     5 ROOM   212      YISHUN ST 21     10 TO 12
# 917527  2012-02      YISHUN     5 ROOM   758      YISHUN ST 72     01 TO 03
# 917528  2012-02      YISHUN     5 ROOM   873      YISHUN ST 81     01 TO 03
# 917529  2012-02      YISHUN  EXECUTIVE   664      YISHUN AVE 4     07 TO 09
# 917530  2012-02      YISHUN  EXECUTIVE   293      YISHUN ST 22     04 TO 06
#
# ...

# %%
data.shape
# Out:
# (917531, 11)

# %%
data.isnull().sum()
# Out:
# month                       0
# town                        0
# flat_type                   0
# block                       0
# street_name                 0
# storey_range                0
# floor_area_sqm              0
# flat_model                  0
# lease_commence_date         0
# resale_price                0
# remaining_lease        709050
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 917531 entries, 0 to 917530
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   month                917531 non-null  object
#  1   town                 917531 non-null  object
#  2   flat_type            917531 non-null  object
#  3   block                917531 non-null  object
#  4   street_name          917531 non-null  object
#  5   storey_range         917531 non-null  object
#  6   floor_area_sqm       917531 non-null  float64
#  7   flat_model           917531 non-null  object
#  8   lease_commence_date  917531 non-null  int64
#  9   resale_price         917531 non-null  float64
#  10  remaining_lease      208481 non-null  object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 77.0+ MB

# %%
data.columns
# Out:
# Index(['month', 'town', 'flat_type', 'block', 'street_name', 'storey_range',
#        'floor_area_sqm', 'flat_model', 'lease_commence_date', 'resale_price',
#        'remaining_lease'],
#       dtype='object')

# %%
# droping remaining_lease missing values
data = data.dropna()
data.isnull().sum()
# Out:
# month                  0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# storey_range           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# resale_price           0
# remaining_lease        0
# dtype: int64

# %%
data.describe()
# Out:
#        floor_area_sqm  lease_commence_date  resale_price
# count   208481.000000        208481.000000  2.084810e+05
# mean        97.222261          1995.008025  4.823848e+05
# std         24.054336            13.595554  1.661293e+05
# min         31.000000          1966.000000  1.400000e+05
# 25%         82.000000          1984.000000  3.600000e+05
# 50%         94.000000          1995.000000  4.500000e+05
# 75%        112.000000          2004.000000  5.700000e+05
# max        280.000000          2022.000000  1.568888e+06

# %% [markdown]
# DATA CLEANING

# %%
data['resale_price'].value_counts()
# Out:
# 400000.0    2585
# 450000.0    2568
# 380000.0    2541
# 420000.0    2514
# 350000.0    2405
#             ...
# 410288.0       1
# 826700.0       1
# 245800.0       1
# 197288.0       1
# 670002.0       1
# Name: resale_price, Length: 4014, dtype: int64

# %%
data.nunique()
# Out:
# month                   109
# town                     26
# flat_type                 7
# block                  2702
# street_name             567
# storey_range             17
# floor_area_sqm          172
# flat_model               21
# lease_commence_date      56
# resale_price           4014
# remaining_lease         720
# dtype: int64

# %%
data.isna().sum()
# Out:
# month                  0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# storey_range           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# resale_price           0
# remaining_lease        0
# dtype: int64

# %%
def convert_to_years(row):
    if pd.notna(row) and isinstance(row, str):
        if 'years' in row:
            parts = row.split()
            years = float(parts[0])
            months = float(parts[2]) if len(parts) > 2 else 0
            return years + months / 12
    return row

# %%
data['remaining_lease'] =data['remaining_lease'].apply(convert_to_years)
# Out:
# <ipython-input-21-e445b96c5f41>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['remaining_lease'] =data['remaining_lease'].apply(convert_to_years)

# %%
# fill null values in remaining_lease with mode beacuse null value more than 25% it will remove affected in accuracy
data['remaining_lease']=data['remaining_lease'].fillna(data['remaining_lease'].mode()[0])
data.tail()
# Out:
# <ipython-input-22-a279a19ae4d0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['remaining_lease']=data['remaining_lease'].fillna(data['remaining_lease'].mode()[0])
#           month    town  flat_type block     street_name storey_range  \
# 547875  2024-01  YISHUN  EXECUTIVE   325     YISHUN CTRL     04 TO 06
# 547876  2024-01  YISHUN  EXECUTIVE   356  YISHUN RING RD     04 TO 06
# 547877  2024-01  YISHUN  EXECUTIVE   360  YISHUN RING RD     04 TO 06
# 547878  2024-01  YISHUN  EXECUTIVE   387  YISHUN RING RD     10 TO 12
# 547879  2024-01  YISHUN  EXECUTIVE   606    YISHUN ST 61     04 TO 06
#
#         floor_area_sqm  flat_model  lease_commence_date  resale_price  \
# ...

# %%
data['remaining_lease'].value_counts()
# Out:
# 68.000000    2588
# 95.000000    2285
# 67.000000    2209
# 69.000000    1908
# 71.000000    1751
#              ...
# 97.083333       2
# 96.833333       1
# 97.583333       1
# 97.750000       1
# 97.250000       1
# Name: remaining_lease, Length: 667, dtype: int64

# %%
data.isna().sum()
# Out:
# month                  0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# storey_range           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# resale_price           0
# remaining_lease        0
# dtype: int64

# %%
data.dtypes
# Out:
# month                   object
# town                    object
# flat_type               object
# block                   object
# street_name             object
# storey_range            object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# resale_price           float64
# remaining_lease        float64
# dtype: object

# %%
data
# Out:
#           month        town  flat_type block        street_name storey_range  \
# 287196  2015-01  ANG MO KIO     3 ROOM   174   ANG MO KIO AVE 4     07 TO 09
# 287197  2015-01  ANG MO KIO     3 ROOM   541  ANG MO KIO AVE 10     01 TO 03
# 287198  2015-01  ANG MO KIO     3 ROOM   163   ANG MO KIO AVE 4     01 TO 03
# 287199  2015-01  ANG MO KIO     3 ROOM   446  ANG MO KIO AVE 10     01 TO 03
# 287200  2015-01  ANG MO KIO     3 ROOM   557  ANG MO KIO AVE 10     07 TO 09
# ...         ...         ...        ...   ...                ...          ...
# 547875  2024-01      YISHUN  EXECUTIVE   325        YISHUN CTRL     04 TO 06
# 547876  2024-01      YISHUN  EXECUTIVE   356     YISHUN RING RD     04 TO 06
# 547877  2024-01      YISHUN  EXECUTIVE   360     YISHUN RING RD     04 TO 06
# 547878  2024-01      YISHUN  EXECUTIVE   387     YISHUN RING RD     10 TO 12
# 547879  2024-01      YISHUN  EXECUTIVE   606       YISHUN ST 61     04 TO 06
#
# ...

# %%
#Month column

# Separate the year and month of resale beacuse this is time series Data
data[['resale_year', 'resale_month']] =data['month'].str.split('-', expand=True)

# drop the resale month column
data.drop('month', axis = 1, inplace= True)

data.head(2)
# Out:
# <ipython-input-27-f3d4aa7aba26>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[['resale_year', 'resale_month']] =data['month'].str.split('-', expand=True)
# <ipython-input-27-f3d4aa7aba26>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[['resale_year', 'resale_month']] =data['month'].str.split('-', expand=True)
# <ipython-input-27-f3d4aa7aba26>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
# Split the 'Range' column into lower and upper bounds
data[['storey_lower_bound', 'storey_upper_bound']]=data['storey_range'].str.split ('TO',expand=True)
# Out:
# <ipython-input-28-0a9e458c38ca>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[['storey_lower_bound', 'storey_upper_bound']]=data['storey_range'].str.split ('TO',expand=True)
# <ipython-input-28-0a9e458c38ca>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[['storey_lower_bound', 'storey_upper_bound']]=data['storey_range'].str.split ('TO',expand=True)

# %%
# Convert the lower and upper bounds to numeric values
data['storey_lower_bound'] = pd.to_numeric(data['storey_lower_bound'])
data['storey_upper_bound'] = pd.to_numeric(data['storey_upper_bound'])

data.tail(2)
# Out:
# <ipython-input-29-fdb4c5865bf2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['storey_lower_bound'] = pd.to_numeric(data['storey_lower_bound'])
# <ipython-input-29-fdb4c5865bf2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['storey_upper_bound'] = pd.to_numeric(data['storey_upper_bound'])
#           town  flat_type block     street_name storey_range  floor_area_sqm  \
# 547878  YISHUN  EXECUTIVE   387  YISHUN RING RD     10 TO 12           146.0
# ...

# %%
data.drop('storey_range', axis = 1, inplace= True)
# Out:
# <ipython-input-30-782226ad3e06>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop('storey_range', axis = 1, inplace= True)

# %%
#  Data type CONVERTING

data['block'] = pd.to_numeric(data['block'], errors='coerce')
data['resale_year'] = pd.to_numeric(data['resale_year'], errors='coerce')
data['resale_month'] = pd.to_numeric(data['resale_month'], errors='coerce')
data['block'] = data['block'].fillna(data['block'].mode()[0])
# Out:
# <ipython-input-31-ff8afad47043>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['block'] = pd.to_numeric(data['block'], errors='coerce')
# <ipython-input-31-ff8afad47043>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['resale_year'] = pd.to_numeric(data['resale_year'], errors='coerce')
# <ipython-input-31-ff8afad47043>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
data.head()
# Out:
#               town flat_type  block        street_name  floor_area_sqm  \
# 287196  ANG MO KIO    3 ROOM  174.0   ANG MO KIO AVE 4            60.0
# 287197  ANG MO KIO    3 ROOM  541.0  ANG MO KIO AVE 10            68.0
# 287198  ANG MO KIO    3 ROOM  163.0   ANG MO KIO AVE 4            69.0
# 287199  ANG MO KIO    3 ROOM  446.0  ANG MO KIO AVE 10            68.0
# 287200  ANG MO KIO    3 ROOM  557.0  ANG MO KIO AVE 10            68.0
#
#             flat_model  lease_commence_date  resale_price  remaining_lease  \
# 287196        Improved                 1986      255000.0             70.0
# 287197  New Generation                 1981      275000.0             65.0
# 287198  New Generation                 1980      285000.0             64.0
# 287199  New Generation                 1979      290000.0             63.0
# 287200  New Generation                 1980      290000.0             64.0
#
#         resale_year  resale_month  storey_lower_bound  storey_upper_bound
# ...

# %% [markdown]
# FINDING THE COLUMNS CONTAINS TEXT

# %%
object_data_cols = [var for var in data.columns if data[var].dtype == 'object']
object_data_cols
# Out:
# ['town', 'flat_type', 'street_name', 'flat_model']

# %%
data['town'].value_counts()
# Out:
# SENGKANG           16928
# WOODLANDS          14727
# PUNGGOL            14283
# JURONG WEST        14144
# TAMPINES           14084
# YISHUN             13908
# BEDOK              11589
# HOUGANG            10487
# CHOA CHU KANG       9569
# ANG MO KIO          8964
# BUKIT MERAH         7935
# BUKIT BATOK         7803
# BUKIT PANJANG       7764
# TOA PAYOH           6502
# PASIR RIS           6331
# KALLANG/WHAMPOA     6273
# QUEENSTOWN          5726
# SEMBAWANG           5620
# GEYLANG             5261
# CLEMENTI            4808
# JURONG EAST         4340
# SERANGOON           3970
# BISHAN              3842
# CENTRAL AREA        1802
# MARINE PARADE       1301
# BUKIT TIMAH          520
# Name: town, dtype: int64

# %%
data['flat_type'].value_counts()
# Out:
# 4 ROOM              87408
# 5 ROOM              51499
# 3 ROOM              50446
# EXECUTIVE           15686
# 2 ROOM               3285
# MULTI-GENERATION       79
# 1 ROOM                 78
# Name: flat_type, dtype: int64

# %%
# Replace 'MULTI-GENERATION' with 'MULTI GENERATION' in the specified column to avoid duplicate
data['flat_type'] = data['flat_type'].str.replace('MULTI-GENERATION', 'MULTI GENERATION')
# Out:
# <ipython-input-36-9ac891028343>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['flat_type'] = data['flat_type'].str.replace('MULTI-GENERATION', 'MULTI GENERATION')

# %%
data['flat_type'].value_counts()
# Out:
# 4 ROOM              87408
# 5 ROOM              51499
# 3 ROOM              50446
# EXECUTIVE           15686
# 2 ROOM               3285
# MULTI GENERATION       79
# 1 ROOM                 78
# Name: flat_type, dtype: int64

# %%
data['street_name'].value_counts()
# Out:
# YISHUN RING RD        3144
# BEDOK RESERVOIR RD    2347
# PUNGGOL DR            2146
# ANG MO KIO AVE 10     2129
# PUNGGOL FIELD         2032
#                       ...
# SEMBAWANG WAY            5
# GEYLANG EAST AVE 2       2
# MARGARET DR              2
# ALJUNIED AVE 2           1
# MARINE PARADE CTRL       1
# Name: street_name, Length: 567, dtype: int64

# %%
data['flat_model'].value_counts()
# Out:
# Model A                   70339
# Improved                  51766
# New Generation            27678
# Premium Apartment         23008
# Simplified                 8488
# Apartment                  7862
# Maisonette                 5933
# Standard                   5905
# DBSS                       3140
# Model A2                   2541
# Type S1                     429
# Model A-Maisonette          381
# Adjoined flat               352
# Type S2                     213
# Terrace                     116
# Premium Apartment Loft      106
# Multi Generation             79
# 2-room                       74
# Improved-Maisonette          29
# 3Gen                         26
# Premium Maisonette           16
# Name: flat_model, dtype: int64

# %%
data['flat_model'] = data['flat_model'].replace({'MODEL A':'Model A','NEW GENERATION':'New Generation',
                                             'IMPROVED':'Improved','PREMIUM APARTMENT':'Premium Apartment',
                                             'MULTI GENERATION':'Multi Generation ','2-ROOM':'2-room',
                                            'SIMPLIFIED':'Simplified','STANDARD':'Standard',
                                             'MAISONETTE':'Maisonette','MULTI GENERATION':'Multi Generation',
                                             'APARTMENT':'Apartment','MODEL A-MAISONETTE':'Model A-Maisonette',
                                             'TERRACE':'Terrace','IMPROVED-MAISONETTE':'Improved-Maisonette'})
# Out:
# <ipython-input-40-80cbbcd19769>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['flat_model'] = data['flat_model'].replace({'MODEL A':'Model A','NEW GENERATION':'New Generation',

# %%
data['flat_model'].value_counts()
# Out:
# Model A                   70339
# Improved                  51766
# New Generation            27678
# Premium Apartment         23008
# Simplified                 8488
# Apartment                  7862
# Maisonette                 5933
# Standard                   5905
# DBSS                       3140
# Model A2                   2541
# Type S1                     429
# Model A-Maisonette          381
# Adjoined flat               352
# Type S2                     213
# Terrace                     116
# Premium Apartment Loft      106
# Multi Generation             79
# 2-room                       74
# Improved-Maisonette          29
# 3Gen                         26
# Premium Maisonette           16
# Name: flat_model, dtype: int64

# %% [markdown]
# FINDING DUPLICATES

# %%
data.duplicated().sum()
# Out:
# 530

# %%
data.drop_duplicates(inplace=True)
data.duplicated().sum()
# Out:
# <ipython-input-43-2a1b40573dc3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop_duplicates(inplace=True)
# 0

# %%
float_data_cols = [var for var in data.columns if data[var].dtype == 'float64']
float_data_cols
# Out:
# ['block', 'floor_area_sqm', 'resale_price', 'remaining_lease']

# %%
integer_data_cols = [var for var in data.columns if data[var].dtype == 'int64']
integer_data_cols
# Out:
# ['lease_commence_date',
#  'resale_year',
#  'resale_month',
#  'storey_lower_bound',
#  'storey_upper_bound']

# %% [markdown]
# PLOTTING - BOX PLOT

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import datetime as dt

import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio

# %%
# Creating plot
plt.boxplot(data['block'] )

# show plot
plt.show()

# %%
# IQR

Q1 = data['block'].quantile(0.25)
Q3 = data['block'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

lower_bound , upper_bound
# Out:
# (-628.0, 1052.0)

# %%
data.block = data.block.clip(lower_bound , upper_bound)
# Out:
# <ipython-input-48-d2d57106388e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.block = data.block.clip(lower_bound , upper_bound)

# %%
# Creating plot
plt.boxplot(data['block'] )

# show plot
plt.show()

# %%
# Creating plot
plt.boxplot(data['floor_area_sqm'] )

# show plot
plt.show()

# %%
Q1 = data['floor_area_sqm'].quantile(0.25)
Q3 = data['floor_area_sqm'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

lower_bound , upper_bound
# Out:
# (37.0, 157.0)

# %%
data.floor_area_sqm = data.floor_area_sqm.clip(lower_bound , upper_bound)
# Out:
# <ipython-input-52-0c4cdadfc61e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.floor_area_sqm = data.floor_area_sqm.clip(lower_bound , upper_bound)

# %%
# Creating plot
plt.boxplot(data['floor_area_sqm'] )

# show plot
plt.show()

# %%
# Creating plot
plt.boxplot(data['resale_price'] )

# show plot
plt.show()

# %%
Q1 = data['resale_price'].quantile(0.25)
Q3 = data['resale_price'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

lower_bound , upper_bound
# Out:
# (45000.0, 885000.0)

# %%
data.resale_price = data.resale_price.clip(lower_bound , upper_bound)
# Out:
# <ipython-input-56-9f700ff4f675>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.resale_price = data.resale_price.clip(lower_bound , upper_bound)

# %%
# Creating plot
plt.boxplot(data['resale_price'] )

# show plot
plt.show()

# %%
# Creating plot
plt.boxplot(data['remaining_lease'] )

# show plot
plt.show()

# %%
Q1 = data['remaining_lease'].quantile(0.25)
Q3 = data['remaining_lease'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

lower_bound , upper_bound
# Out:
# (31.624999999999993, 117.29166666666669)

# %%
data.remaining_lease = data.remaining_lease.clip(lower_bound , upper_bound)
# Out:
# <ipython-input-60-195eb34e9550>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.remaining_lease = data.remaining_lease.clip(lower_bound , upper_bound)

# %%
# Creating plot
plt.boxplot(data['remaining_lease'] )

# show plot
plt.show()

# %%
# Creating plot
plt.boxplot(data['lease_commence_date'] )

# show plot
plt.show()

# %%
# Creating plot
plt.boxplot(data['storey_lower_bound'] )

# show plot
plt.show()

# %%
Q1 = data['storey_lower_bound'].quantile(0.25)
Q3 = data['storey_lower_bound'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

lower_bound , upper_bound
# Out:
# (-5.0, 19.0)

# %%
data.storey_lower_bound = data.storey_lower_bound.clip(lower_bound , upper_bound)
# Out:
# <ipython-input-66-581d8e8cb625>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.storey_lower_bound = data.storey_lower_bound.clip(lower_bound , upper_bound)

# %%
# Creating plot
plt.boxplot(data['storey_lower_bound'] )

# show plot
plt.show()

# %%
# Creating plot
plt.boxplot(data['storey_upper_bound'] )

# show plot
plt.show()

# %%
Q1 = data['storey_upper_bound'].quantile(0.25)
Q3 = data['storey_upper_bound'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

lower_bound , upper_bound
# Out:
# (-3.0, 21.0)

# %%
data.storey_upper_bound = data.storey_upper_bound.clip(lower_bound , upper_bound)
# Out:
# <ipython-input-70-73bbc9eaf1ee>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.storey_upper_bound = data.storey_upper_bound.clip(lower_bound , upper_bound)

# %%
# Creating plot
plt.boxplot(data['storey_upper_bound'] )

# show plot
plt.show()

# %% [markdown]
# EDA - EXPLORATARY DATA ANALYSIS
# Categorical Vs Frequency using BarPlot

# %%
object_data_cols = [var for var in data.columns if data[var].dtype == 'object']
object_data_cols
# Out:
# ['town', 'flat_type', 'street_name', 'flat_model']

# %%
plt.figure(figsize=(20, 25))



plt.subplot(431)
data['town'].value_counts().sort_values(ascending=False).plot(kind='bar', edgecolor='k')
plt.title('town')
plt.xlabel('town')
plt.ylabel('Frequency')
plt.xticks(rotation=15)

plt.subplot(432)
data['flat_type'].value_counts().sort_values(ascending=False).plot(kind='bar', edgecolor='k')
plt.title('flat_type')
plt.xlabel('flat_type')
plt.ylabel('Frequency')

plt.subplot(433)
data['street_name'].value_counts().sort_values(ascending=False).plot(kind='bar', edgecolor='k')
plt.title('street_name')
plt.xlabel('street_name')
plt.ylabel('Frequency')

plt.subplot(434)
data['flat_model'].value_counts().sort_values(ascending=False).plot(kind='bar', edgecolor='k')
plt.title('flat_model')
plt.xlabel('flat_model')
plt.ylabel('Frequency')

plt.subplot(435)
data['resale_year'].value_counts().sort_values(ascending=False).plot(kind='bar', edgecolor='k')
plt.title('resale_year')
plt.xlabel('resale_year')
plt.ylabel('Frequency')

plt.subplot(436)
data['resale_month'].value_counts().sort_values(ascending=False).plot(kind='bar', edgecolor='k')
plt.title('resale_month')
plt.xlabel('resale_month')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# Feature Vs Target (Categorical Data )

# %%
# List of features to plot
features = [
    'town',
 'flat_type',
 'street_name',
 'flat_model',
 'resale_year',
 'resale_month'
]
for feature in features:
    plt.figure(figsize=(10, 6))
    data.groupby(feature)['resale_price'].mean().plot(kind='bar')
    plt.xlabel(feature)
    plt.ylabel('Mean resale_price')
    plt.title(f'{feature} vs Mean Flight_Price')
    plt.show()

# %% [markdown]
# Feature Vs Target (Condinues Data )

# %%
float_data_cols = [var for var in data.columns if data[var].dtype == 'float64']
float_data_cols
# Out:
# ['block', 'floor_area_sqm', 'resale_price', 'remaining_lease']

# %%
integer_data_cols = [var for var in data.columns if data[var].dtype == 'int64']
integer_data_cols
# Out:
# ['lease_commence_date',
#  'resale_year',
#  'resale_month',
#  'storey_lower_bound',
#  'storey_upper_bound']

# %%
features = [ 'block',
 'floor_area_sqm',
 'lease_commence_date',
 'resale_price',
 'remaining_lease',
'storey_lower_bound',
'storey_upper_bound']
target = 'resale_price'
for feature in features:
    plt.figure(figsize=(10, 6))
    plt.scatter(data[feature], data[target], alpha=0.5)
    plt.xlabel(feature)
    plt.ylabel(target)
    plt.title(f'{feature} vs {target}')
    plt.show()

# %% [markdown]
# Encoding Categorical Variables

# %%
#using encoding make a copy
df1=data.copy()

object_data_cols = [var for var in data.columns if data[var].dtype == 'object']
object_data_cols
# Out:
# ['town', 'flat_type', 'street_name', 'flat_model']

# %%
from sklearn.preprocessing import LabelEncoder
# Initialize the Encoder
le= LabelEncoder()

# %%
# list unique street names
streets = df1['street_name'].unique()
# map the streets to povide input to ML model
streets_mapping = {street: idx + 1 for idx, street in enumerate(streets)}
streets_mapping
# Out:
# {'ANG MO KIO AVE 4': 1,
#  'ANG MO KIO AVE 10': 2,
#  'ANG MO KIO AVE 5': 3,
#  'ANG MO KIO AVE 8': 4,
#  'ANG MO KIO AVE 1': 5,
#  'ANG MO KIO AVE 3': 6,
#  'ANG MO KIO AVE 6': 7,
#  'ANG MO KIO ST 52': 8,
#  'ANG MO KIO ST 21': 9,
#  'ANG MO KIO ST 31': 10,
#  'BEDOK RESERVOIR RD': 11,
#  'BEDOK STH RD': 12,
#  'BEDOK NTH ST 3': 13,
#  'BEDOK NTH AVE 1': 14,
#  'BEDOK NTH RD': 15,
#  'NEW UPP CHANGI RD': 16,
#  'CHAI CHEE ST': 17,
#  'BEDOK NTH ST 1': 18,
#  'BEDOK NTH AVE 4': 19,
#  'BEDOK NTH ST 2': 20,
#  'CHAI CHEE AVE': 21,
#  'BEDOK NTH AVE 3': 22,
#  'BEDOK STH AVE 1': 23,
#  'BEDOK CTRL': 24,
#  'BEDOK NTH AVE 2': 25,
#  'BEDOK STH AVE 2': 26,
#  'BEDOK RESERVOIR VIEW': 27,
#  'CHAI CHEE RD': 28,
#  'JLN TENAGA': 29,
#  'BEDOK STH AVE 3': 30,
#  'LENGKONG TIGA': 31,
#  'SHUNFU RD': 32,
#  'BISHAN ST 24': 33,
#  'BISHAN ST 12': 34,
#  'BISHAN ST 22': 35,
#  'BISHAN ST 13': 36,
#  'BISHAN ST 23': 37,
#  'BRIGHT HILL DR': 38,
#  'SIN MING AVE': 39,
#  'BT BATOK ST 52': 40,
# ...

# %%
# list unique street names
streets = df1['street_name'].unique()
# map the streets to povide input to ML model
streets_mapping = {street: idx + 1 for idx, street in enumerate(streets)}
streets_mapping
# Out:
# {'ANG MO KIO AVE 4': 1,
#  'ANG MO KIO AVE 10': 2,
#  'ANG MO KIO AVE 5': 3,
#  'ANG MO KIO AVE 8': 4,
#  'ANG MO KIO AVE 1': 5,
#  'ANG MO KIO AVE 3': 6,
#  'ANG MO KIO AVE 6': 7,
#  'ANG MO KIO ST 52': 8,
#  'ANG MO KIO ST 21': 9,
#  'ANG MO KIO ST 31': 10,
#  'BEDOK RESERVOIR RD': 11,
#  'BEDOK STH RD': 12,
#  'BEDOK NTH ST 3': 13,
#  'BEDOK NTH AVE 1': 14,
#  'BEDOK NTH RD': 15,
#  'NEW UPP CHANGI RD': 16,
#  'CHAI CHEE ST': 17,
#  'BEDOK NTH ST 1': 18,
#  'BEDOK NTH AVE 4': 19,
#  'BEDOK NTH ST 2': 20,
#  'CHAI CHEE AVE': 21,
#  'BEDOK NTH AVE 3': 22,
#  'BEDOK STH AVE 1': 23,
#  'BEDOK CTRL': 24,
#  'BEDOK NTH AVE 2': 25,
#  'BEDOK STH AVE 2': 26,
#  'BEDOK RESERVOIR VIEW': 27,
#  'CHAI CHEE RD': 28,
#  'JLN TENAGA': 29,
#  'BEDOK STH AVE 3': 30,
#  'LENGKONG TIGA': 31,
#  'SHUNFU RD': 32,
#  'BISHAN ST 24': 33,
#  'BISHAN ST 12': 34,
#  'BISHAN ST 22': 35,
#  'BISHAN ST 13': 36,
#  'BISHAN ST 23': 37,
#  'BRIGHT HILL DR': 38,
#  'SIN MING AVE': 39,
#  'BT BATOK ST 52': 40,
# ...

# %%
# alter the column with the mapped numbers
df1['street_name'] = df1['street_name'].map(streets_mapping)

# Display the DataFrame
df1.head(2)
# Out:
#               town flat_type  block  street_name  floor_area_sqm  \
# 287196  ANG MO KIO    3 ROOM  174.0            1            60.0
# 287197  ANG MO KIO    3 ROOM  541.0            2            68.0
#
#             flat_model  lease_commence_date  resale_price  remaining_lease  \
# 287196        Improved                 1986      255000.0             70.0
# 287197  New Generation                 1981      275000.0             65.0
#
#         resale_year  resale_month  storey_lower_bound  storey_upper_bound
# 287196         2015             1                   7                   9
# 287197         2015             1                   1                   3

# %%
df1['flat_type'].unique()
# Out:
# array(['3 ROOM', '4 ROOM', '5 ROOM', '2 ROOM', 'EXECUTIVE', '1 ROOM',
#        'MULTI GENERATION'], dtype=object)

# %%
category_mapping = {
    '1 ROOM': 1,
    '2 ROOM': 2,
    '3 ROOM': 3,
    '4 ROOM': 4,
    '5 ROOM': 5,
    'EXECUTIVE': 6,
    'MULTI GENERATION': 7
}

# alter the column with the mapped numbers
df1['flat_type'] =df1['flat_type'].map(category_mapping)

# Display the DataFrame
df1.head(2)
# Out:
#               town  flat_type  block  street_name  floor_area_sqm  \
# 287196  ANG MO KIO          3  174.0            1            60.0
# 287197  ANG MO KIO          3  541.0            2            68.0
#
#             flat_model  lease_commence_date  resale_price  remaining_lease  \
# 287196        Improved                 1986      255000.0             70.0
# 287197  New Generation                 1981      275000.0             65.0
#
#         resale_year  resale_month  storey_lower_bound  storey_upper_bound
# 287196         2015             1                   7                   9
# 287197         2015             1                   1                   3

# %%
# Create a mapping of 'flat_model' values to numbers
flat_model_mapping = {
    'IMPROVED': 1,
    'NEW GENERATION': 2,
    'MODEL A': 3,
    'STANDARD': 4,
    'SIMPLIFIED': 5,
    'MODEL A-MAISONETTE': 6,
    'APARTMENT': 7,
    'MAISONETTE': 8,
    'TERRACE': 9,
    '2-ROOM': 10,
    'IMPROVED-MAISONETTE': 11,
    'MULTI GENERATION': 12,
    'PREMIUM APARTMENT': 13,
    'Improved': 14,
    'New Generation': 15,
    'Model A': 16,
    'Standard': 17,
    'Apartment': 18,
    'Simplified': 19,
    'Model A-Maisonette': 20,
    'Maisonette': 21,
    'Multi Generation': 22,
    'Adjoined flat': 23,
    'Premium Apartment': 24,
    'Terrace': 25,
    'Improved-Maisonette': 26,
    'Premium Maisonette': 27,
    '2-room': 28,
    'Model A2': 29,
    'DBSS': 30,
    'Type S1': 31,
    'Type S2': 32,
    'Premium Apartment Loft': 33,
    '3Gen': 34
}

# Map 'flat_model' values to numbers
df1['flat_model'] =df1['flat_model'].map(flat_model_mapping)

# Display the DataFrame
df1.head(3)
# Out:
#               town  flat_type  block  street_name  floor_area_sqm  flat_model  \
# 287196  ANG MO KIO          3  174.0            1            60.0          14
# 287197  ANG MO KIO          3  541.0            2            68.0          15
# 287198  ANG MO KIO          3  163.0            1            69.0          15
#
#         lease_commence_date  resale_price  remaining_lease  resale_year  \
# 287196                 1986      255000.0             70.0         2015
# 287197                 1981      275000.0             65.0         2015
# 287198                 1980      285000.0             64.0         2015
#
#         resale_month  storey_lower_bound  storey_upper_bound
# 287196             1                   7                   9
# 287197             1                   1                   3
# 287198             1                   1                   3

# %%
# Create a mapping of 'town' values to numbers
town_mapping = {
    'ANG MO KIO': 1,
    'BEDOK': 2,
    'BISHAN': 3,
    'BUKIT BATOK': 4,
    'BUKIT MERAH': 5,
    'BUKIT TIMAH': 6,
    'CENTRAL AREA': 7,
    'CHOA CHU KANG': 8,
    'CLEMENTI': 9,
    'GEYLANG': 10,
    'HOUGANG': 11,
    'JURONG EAST': 12,
    'JURONG WEST': 13,
    'KALLANG/WHAMPOA': 14,
    'MARINE PARADE': 15,
    'QUEENSTOWN': 16,
    'SENGKANG': 17,
    'SERANGOON': 18,
    'TAMPINES': 19,
    'TOA PAYOH': 20,
    'WOODLANDS': 21,
    'YISHUN': 22,
    'LIM CHU KANG': 23,
    'SEMBAWANG': 24,
    'BUKIT PANJANG': 25,
    'PASIR RIS': 26,
    'PUNGGOL': 27
}

# Map 'town' values to numbers
df1['town'] = df1['town'].map(town_mapping)

# Display the DataFrame
df1.head(4)
# Out:
#         town  flat_type  block  street_name  floor_area_sqm  flat_model  \
# 287196     1          3  174.0            1            60.0          14
# 287197     1          3  541.0            2            68.0          15
# 287198     1          3  163.0            1            69.0          15
# 287199     1          3  446.0            2            68.0          15
#
#         lease_commence_date  resale_price  remaining_lease  resale_year  \
# 287196                 1986      255000.0             70.0         2015
# 287197                 1981      275000.0             65.0         2015
# 287198                 1980      285000.0             64.0         2015
# 287199                 1979      290000.0             63.0         2015
#
#         resale_month  storey_lower_bound  storey_upper_bound
# 287196             1                   7                   9
# 287197             1                   1                   3
# ...

# %%
# save the processed data for the deployment
df1.to_csv('final.csv')

# %% [markdown]
# Correlation

# %%
# correlation matrix (ranges from 1 to -1)
corrm=df1.corr()
#corrm.to_csv('corrm.csv')
corrm
# Out:
#                          town  flat_type     block  street_name  \
# town                 1.000000   0.165539 -0.039611     0.570307
# flat_type            0.165539   1.000000  0.092929     0.067125
# block               -0.039611   0.092929  1.000000    -0.140487
# street_name          0.570307   0.067125 -0.140487     1.000000
# floor_area_sqm       0.145059   0.954422  0.178800     0.046327
# flat_model           0.166259   0.184714 -0.097244     0.131804
# lease_commence_date  0.347150   0.221535 -0.302565     0.353052
# resale_price        -0.017762   0.630752 -0.153323     0.097473
# remaining_lease      0.347417   0.227674 -0.286668     0.337594
# resale_year          0.040178  -0.005779 -0.105297     0.119076
# resale_month         0.006763   0.004004 -0.007576     0.011266
# storey_lower_bound  -0.009446   0.046898 -0.191924     0.037404
# storey_upper_bound  -0.009446   0.046898 -0.191924     0.037404
#
# ...

# %% [markdown]
# HEATMAP

# %%
# visualize correlation matrix in Seaborn using a heatmap
plt.figure(figsize=(16,6))
sns.heatmap(corrm,annot=True,cmap="Blues",fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
#  MEACHIN LEARNING

# %% [markdown]
# SPLIT

# %%
# assign feature and target variable
X = df1.drop('resale_price', axis= 1)
y = df1['resale_price']
#splitting the data into training and testing sets with the ratio of 8:2
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=72)

# %%
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (166360, 12) (41591, 12) (166360,) (41591,)

# %% [markdown]
# SCALLLING

# %% [markdown]
# MODEL FIT

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_train_scaled ,X_test_scaled
# Out:
# (array([[-1.76275952, -0.13553905,  1.14927265, ...,  0.98591741,
#          -1.28640782, -1.28640782],
#         [-0.24068484, -1.22277937,  0.9404692 , ..., -1.0670033 ,
#          -1.28640782, -1.28640782],
#         [-0.74804307, -1.22277937,  0.35581955, ...,  0.98591741,
#          -0.07608531, -0.07608531],
#         ...,
#         [-1.50908041, -0.13553905, -0.38448357, ...,  0.10609425,
#           0.52907594,  0.52907594],
#         [ 1.40822939,  0.95170126,  1.84781508, ...,  0.39936864,
#          -0.68124657, -0.68124657],
#         [ 0.77403161,  0.95170126, -0.87422257, ..., -0.77372891,
#          -0.07608531, -0.07608531]]),
#  array([[ 0.01299427,  0.95170126, -0.58569417, ..., -1.0670033 ,
#           0.52907594,  0.52907594],
#         [ 1.40822939,  0.95170126,  1.21760832, ..., -0.77372891,
#          -1.28640782, -1.28640782],
#         [ 1.53506895, -0.13553905, -0.87422257, ...,  0.98591741,
#           1.13423719,  1.13423719],
#         ...,
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

import xgboost as xgb
from xgboost import XGBRegressor  # Use XGBRegressor for regression

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# LINEAR REGRESSION

# %%
linear_model = LinearRegression(fit_intercept=True) #initialise
linear_model.fit(X_train,y_train) #fit - all magic
print(linear_model.predict(X_test))     #predict
print(y_test)
# Out:
# [529482.62966526 379073.52260933 569962.3569433  ... 497119.69076508
#  451884.62932868 538086.75509986]
# 290341    880000.0
# 291888    436000.0
# 508866    625888.0
# 315794    426000.0
# 489330    455000.0
#             ...
# 380235    540000.0
# 415359    290000.0
# 533825    550000.0
# 401042    400000.0
# 380283    640000.0
# Name: resale_price, Length: 41591, dtype: float64

# %%
linear_model.score(X_test, y_test)
# Out:
# 0.6481684131538406

# %%
from sklearn.model_selection import cross_val_score
cross_val_linear_model=cross_val_score(linear_model,X_train,y_train,cv=10).mean()
cross_val_linear_model
# Out:
# 0.6514459510890904

# %% [markdown]
# K Nearest Neighbor Regression

# %%
import numpy as np

# %%
# Create and train the K Nearest Neighbor Regression model
knn_regressor = KNeighborsRegressor(n_neighbors=5)  # You may need to adjust the number of neighbors
knn_regressor.fit(X_train_scaled, y_train)

# Make predictions on the test set using KNN model
y_pred_knn = knn_regressor.predict(X_test_scaled)

# Calculate Mean Absolute Error (MAE)
mae_knn = mean_absolute_error(y_test, y_pred_knn)

# Calculate Mean Squared Error (MSE)
mse_knn = mean_squared_error(y_test, y_pred_knn)

# Calculate Root Mean Squared Error (RMSE)
rmse_knn = np.sqrt(mse_knn)

# Calculate R-squared (R2) Score
r2_knn = r2_score(y_test, y_pred_knn)

print("Mean Absolute Error (MAE)    :", mae_knn)
print("Mean Squared Error (MSE)     :", mse_knn)
print("Root Mean Square Error (RMSE):", rmse_knn)
print("R-squared (R2) Score         :", r2_knn)
# Out:
# Mean Absolute Error (MAE)    : 39123.573879589334
# Mean Squared Error (MSE)     : 3651819280.492142
# Root Mean Square Error (RMSE): 60430.28446476272
# R-squared (R2) Score         : 0.8558166587964955

# %% [markdown]
# Decision Tree Regression

# %%
# Create and train the Decision Tree Regressor model
dt_regressor = DecisionTreeRegressor(max_depth=20, random_state=11)
dt_regressor.fit(X_train, y_train)

# Make predictions on the test set using Decision Tree model
y_pred_dt = dt_regressor.predict(X_test)

# Calculate Mean Absolute Error (MAE)
mae_dt = mean_absolute_error(y_test, y_pred_dt)

# Calculate Mean Squared Error (MSE)
mse_dt = mean_squared_error(y_test, y_pred_dt)

# Calculate Root Mean Squared Error (RMSE)
rmse_dt = np.sqrt(mse_dt)

# Calculate R-squared (R2) Score
r2_dt = r2_score(y_test, y_pred_dt)

print("Mean Absolute Error (MAE)    :", mae_dt)
print("Mean Squared Error (MSE)     :", mse_dt)
print("Root Mean Square Error (RMSE):", rmse_dt)
print("R-squared (R2) Score         :", r2_dt)
# Out:
# Mean Absolute Error (MAE)    : 24459.10806104627
# Mean Squared Error (MSE)     : 1322088591.714256
# Root Mean Square Error (RMSE): 36360.536185736535
# R-squared (R2) Score         : 0.9478004972648296

# %% [markdown]
# Random Forest Regression

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Create and train the Random Forest Regressor model
rf_regressor = RandomForestRegressor(random_state=42)
rf_regressor.fit(X_train, y_train)

# Make predictions on the test set
y_pred = rf_regressor.predict(X_test)

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, y_pred)

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)

# Calculate Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)

# Calculate R-squared (R2) Score
rf_r2 = r2_score(y_test, y_pred)

print("Mean Absolute Error (MAE)    :", mae)
print("Mean Squared Error (MSE)     :", mse)
print("Root Mean Square Error (RMSE):", rmse)
print("R-squared (R2) Score         :", rf_r2)
# Out:
# Mean Absolute Error (MAE)    : 19284.4626231323
# Mean Squared Error (MSE)     : 743439451.7668382
# Root Mean Square Error (RMSE): 27266.086110163265
# R-squared (R2) Score         : 0.9706470731695687

# %% [markdown]
# Xg Boost Regression

# %%
# Create and train an XGBoost regressor
xgregressor = XGBRegressor()
xgregressor.fit(X_train, y_train)

# Make predictions
y_pred = xgregressor.predict(X_test)

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, y_pred)

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_pred)

# Calculate Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)

# Calculate R-squared (R2) Score
xgb_r2 = r2_score(y_test, y_pred)

print("Mean Absolute Error (MAE)    :", mae)
print("Mean Squared Error (MSE)     :", mse)
print("Root Mean Square Error (RMSE):", rmse)
print("R-squared (R2) Score         :", xgb_r2)
# Out:
# Mean Absolute Error (MAE)    : 21974.996233785554
# Mean Squared Error (MSE)     : 883760896.258791
# Root Mean Square Error (RMSE): 29728.116258161917
# R-squared (R2) Score         : 0.9651068168876025

# %% [markdown]
# **Finalizing Models**

# %%
models = [ 'KNeighborsRegressor','DecisionTreeRegressor', 'RandomForestRegressor', 'XGBRegressor']
score = [r2_knn,r2_dt, rf_r2, xgb_r2]

fig=px.bar(x=models, y=score,title='R_2 of Regression Models')
fig.show()

print("FINDING BEST FIT MODEL FOR EVALUATION BASED ON R_2 SCORE\n")
max_score = max(score)  # Initialize max_score with the maximum value in the score list
max_model = ""

for model, score_value in zip(models, score):
    print(model, score_value)
    if score_value == max_score:
        max_model = model

print(f"\nModel: {max_model} contain Maximum R2_Score: {max_score} ")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ***Suggestion***

# %%
rf_regressor.feature_importances_
# Out:
# array([0.15540611, 0.0259603 , 0.03079914, 0.05056261, 0.44269589,
#        0.02304576, 0.1133095 , 0.01677501, 0.09154668, 0.00721105,
#        0.02288777, 0.0198002 ])

# %%
sorted_idx = rf_regressor.feature_importances_.argsort()
plt.figure(figsize=(10,5))
plt.barh(data.columns[sorted_idx], rf_regressor.feature_importances_[sorted_idx])
plt.xlabel("Random Forest Feature Importance")
plt.title("Feature Importance")

plt.show()

# %% [markdown]
# Save the model

# %%
model=rf_regressor.fit(X_train, y_train)

# %%
model
# Out:
# RandomForestRegressor(random_state=42)

# %%
import pickle
with open('randomfroestregressor.pkl','wb') as file:
  pickle.dump(model,file)

# %% [markdown]
# Predicting

# %%
# get sample to predict the resale price
pre_df =df1.sample(n=5)
pre_df
# Out:
#         town  flat_type  block  street_name  floor_area_sqm  flat_model  \
# 534450    27          4    2.0          240            92.0          16
# 538956    17          6    2.0          271           127.0          18
# 321200    21          4  662.0          359           100.0          16
# 320713    27          4    2.0          239            94.0          16
# 425354     5          3   14.0          480            54.0          17
#
#         lease_commence_date  resale_price  remaining_lease  resale_year  \
# 534450                 2014      590000.0        90.083333         2023
# 538956                 2002      740000.0        77.500000         2023
# 321200                 1998      345000.0        80.000000         2016
# 320713                 2012      430000.0        95.000000         2016
# 425354                 1970      258000.0        49.750000         2019
#
#         resale_month  storey_lower_bound  storey_upper_bound
# ...

# %%
# drop the resale price column
A = pre_df.drop('resale_price', axis = 1)

# %% [markdown]
# RESALE PRICE

# %%
# Make predictions on the sample
pre_pred = rf_regressor.predict(A)
pre_pred
# Out:
# array([585635.44      , 735746.        , 361172.64      , 436918.47714286,
#        270246.        ])

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.2.2
